# %%
import random

class HraChramst:
    def __init__(self):
        #inicializuj hru:
        self.deck = [1, 2, 3, 4, 5, 6]
        self.players = ["modry","zlty","cerveny","zeleny"] 
        
        
    def karty(self):
        karty_na_ruke = self.deck.copy() #nezmeni sa mi povodny deck
        print(f"Karty na ruke: {karty_na_ruke}")
        zahraj_kartu = input(f"Zahraj jednu z kariet: {karty_na_ruke} ")
        print(f" zahral si kartu {zahraj_kartu} a bola ti odobrana z kariet na ruke")
        
        
        
       
       

        
        
        
        
    def zaciatok_poradie_hracov(self):
#na zaciatku hry treba randomne urcit poradie hracov v akom sa zacne hra
#random.sample vytvara novy nahodny zoznam, povodny je nezmeneny
#random.sample(sequence, k) : sequence	Required. A sequence. Can be any sequence: list, set, range etc.
#k	Required. The size of the returned list
        poradie_zaciatok = random.sample(self.players, k=4)   
        print(f"Hraci zacinaju v nasledovnom poradi: {', '.join(poradie_zaciatok)}")       
        
        
    
    def zaciatok_hry(self):
        pass
    
    def pohyby(self):
        pass
    
    def vyhodnotenie_kola(self):
        pass
    
    
    def hra(self, karty_na_ruke):
    
            
        pass
    
    def pocitanie_zivotov(self):
        pass
    
 
nieco = HraChramst()
nieco.zaciatok_poradie_hracov()
nieco.karty()
# Out:
# Hraci zacinaju v nasledovnom poradi: modry, zeleny, cerveny, zlty
# Karty na ruke: [1, 2, 3, 4, 5, 6]
#  zahral si kartu 1 a bola ti odobrana z kariet na ruke

# %%
# zadefinovanie hracov
hraci = ["Modry", "Zlty", "Zeleny", "Cerveny"]
zivoty = 4

#zadefinovanie kariet
karty = [1, 2, 3, 4, 5, 6]

# karty na ruke, definicia
karty_na_ruke = karty.copy()
odhadzovaci_balicek = []

pozicia_hracov = []

def pohyby():
    pass

def zahraj_kartu():
    vyber_kartu = int(input(f"Vyber si kartu co chces zahrat{karty_na_ruke}"))
    
    print(f"zahral si kartu {vyber_kartu}")
    if vyber_kartu not in karty_na_ruke:
        print(f"Cislo {vyber_kartu} nie je spravne. Vyber si jednu z kariet co mas na ruke")
    else:
       karty_na_ruke.remove(vyber_kartu)
       return odhadzovaci_balicek.append(vyber_kartu)
   
   
def pocet_zivotov():
    pass

def vyhodnotenie_kol():
    
   

        
       
         

zahraj_kartu()
print(f"zostavajuce karty na ruke{karty_na_ruke}")     
print(f"karty v odhahdozvacom balicku {odhadzovaci_balicek}")
# Out:
# zahral si kartu 1
# zostavajuce karty na ruke[2, 3, 4, 5, 6]
# karty v odhahdozvacom balicku [1]

# %%
class Chramst:
    def __init__(self):
        self.hraci = {
            "Modry": {"poradie": 1, "zivoty": 3},
            "Zlty": {"poradie": 2, "zivoty": 3},
            "Zeleny": {"poradie": 3, "zivoty": 3},
            "Cerveny": {"poradie": 4, "zivoty": 3}
        }
    
    def zobraz_hracov(self):
        for meno, data in self.hraci.items():
            print(f"{meno}: {data['poradie']}. miesto, Zivoty: {data['zivoty']}")
    
    def uber_zivot(self, hrac):
        self.hraci[hrac]["zivoty"] -= 1
        if self.hraci[hrac]["zivoty"] <= 0:
            print(f"{hrac} prehral - nema zivoty!")
    
    def zmen_poradie(self, hrac, nove_poradie):
        self.hraci[hrac]["poradie"] = nove_poradie

# Použitie:
hra = Chramst()
hra.zobraz_hracov()
# Modry: 1. miesto, Zivoty: 3
# Zlty: 2. miesto, Zivoty: 3
# ...

hra.uber_zivot("Modry")
hra.zmen_poradie("Zeleny", 1)
hra.zobraz_hracov()

# %%
class Chramst:
    def __init__(self):
        self.karty_na_ruke = [1, 2, 3, 4, 5, 6]
        self.hraci = {
            "Modry": {"poradie": 1, "zivoty": 4, "karty na ruke": self.karty_na_ruke},
            "Zlty": {"poradie": 2, "zivoty": 4, "karty na ruke": self.karty_na_ruke},
            "Zeleny": {"poradie": 3, "zivoty": 4, "karty na ruke": self.karty_na_ruke},
            "Cerveny": {"poradie": 4, "zivoty": 4, "karty na ruke": self.karty_na_ruke}
        }
        
        self.odhadzovaci_balicek = []
        self.pozicia_hracov = []
        
    def zobraz_hracov(self):
        for meno, info in self.hraci.items():
            print(f"{meno}: {info['poradie']}. miesto, Zivoty: {info['zivoty']}. karty na ruke: {info['karty na ruke']} ")
            
     
        
    def zahraj_kartu(self):
        vyber_kartu = int(input(f"Vyber si kartu co chces zahrat {self.karty_na_ruke}: "))
        
        if vyber_kartu not in self.karty_na_ruke:
            print(f"Cislo {vyber_kartu} nie je spravne. Vyber si jednu z kariet co mas na ruke")
        else:
            print(f"Zahral si kartu {vyber_kartu}")
            self.karty_na_ruke.remove(vyber_kartu)
            self.odhadzovaci_balicek.append(vyber_kartu)
            print(f"Zostavajuce karty na ruke: {hra.karty_na_ruke}")
            print(f"Karty v odhadzovanom balicku: {hra.odhadzovaci_balicek}")
        
        


# Vytvorenie instance hry a zahranie karty
hra = Chramst()
hra.zobraz_hracov()
hra.zahraj_kartu()
